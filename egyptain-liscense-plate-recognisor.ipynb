# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/14.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/18.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/16.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/22.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/24.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/6.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/9.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/4.png
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/11.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/20.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/4.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/5.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/2.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/19.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/1.png
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/7.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/2.png
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/21.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/23.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/1.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/17.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/3.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/13.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/15.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/10.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/3.png
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/8.jpeg
# /kaggle/input/egy-platesv1/Egy_Plates_Imgs/12.jpeg
# /kaggle/input/lisence-plate-detector-weights/tensorflow2/default/1/best.pt
# /kaggle/input/egycar-vs-distance/plate_Vs_distance/18m.jpeg
# /kaggle/input/egycar-vs-distance/plate_Vs_distance/6m.jpeg
# /kaggle/input/egycar-vs-distance/plate_Vs_distance/15m.jpeg
# /kaggle/input/egycar-vs-distance/plate_Vs_distance/9m.jpeg
# /kaggle/input/egycar-vs-distance/plate_Vs_distance/12m.jpeg
# /kaggle/input/egycar-vs-distance/plate_Vs_distance/3m.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/14.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/18.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/16.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/44.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/31.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/25.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/43.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/27.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/22.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/24.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/6.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/9.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/45.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/11.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/20.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/28.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/47.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/39.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/32.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/4.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/5.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/2.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/42.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/33.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/19.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/50.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/30.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/7.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/46.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/52.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/37.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/21.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/23.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/51.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/1.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/17.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/3.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/35.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/13.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/49.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/36.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/15.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/34.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/10.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/29.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/41.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/8.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/48.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/12.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/38.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/26.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/40.jpeg
# /kaggle/input/egy-carsv1/Egy_Cars_Imgs/53.jpeg

# %%
# !pip install ultralytics
# Out:
# Collecting ultralytics
#   Downloading ultralytics-8.3.81-py3-none-any.whl.metadata (35 kB)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Collecting ultralytics-thop>=2.0.0 (from ultralytics)
#   Downloading ultralytics_thop-2.0.14-py3-none-any.whl.metadata (9.4 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Downloading ultralytics-8.3.81-py3-none-any.whl (922 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 922.1/922.1 kB 16.4 MB/s eta 0:00:00
# Downloading ultralytics_thop-2.0.14-py3-none-any.whl (26 kB)
# Installing collected packages: ultralytics-thop, ultralytics
# Successfully installed ultralytics-8.3.81 ultralytics-thop-2.0.14

# %%
from ultralytics import YOLO
from IPython.display import display, Image
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
# !pip install roboflow

# from roboflow import Roboflow
# rf = Roboflow(api_key="DTywvqb9qrh51hE7n9XR")
# project = rf.workspace("roboflow-universe-projects").project("license-plate-recognition-rxg4e")
# version = project.version(6)
# dataset = version.download("yolov11")

# %%
#!yolo task=detect mode=train model=yolo11n.pt data='/kaggle/working/License-Plate-Recognition-6/data.yaml' epochs=100 imgsz=640 device=0,1 batch=128 project=/kaggle/working/runs name=train_results save_period=25

# %%
# import os
# from PIL import Image
# import matplotlib.pyplot as plt
# # Define the path to the train_results3 folder
# folder_path = '/kaggle/working/runs/train_results3'

# # Get a list of all image files in the folder
# image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# # Load and display images in separate figures
# for image_file in image_files:
#     # Load the image
#     img_path = os.path.join(folder_path, image_file)
#     img = Image.open(img_path)
    
#     # Create a new figure for each image
#     plt.figure(figsize=(8, 6))
#     plt.imshow(img)
#     plt.title(os.path.basename(img_path))
#     plt.axis('off')
#     plt.show()

# %%
# # Step 1: Install Required Libraries
# !pip install ultralytics matplotlib pillow

# # Step 2: Import Libraries
# import os
# from PIL import Image
# import matplotlib.pyplot as plt
# import math

# # Step 3: Define Paths
# weights_path = '/kaggle/working/runs/train_results3/weights/best.pt'  # Path to your trained weights
# dataset_path = '/kaggle/input/egy-carsv1/Egy_Cars_Imgs'  # Path to the dataset folder containing test images
# output_path = '/kaggle/working/predictions1'   # Path to save prediction outputs

# # Create the output directory if it doesn't exist
# os.makedirs(output_path, exist_ok=True)

# # Step 4: Run Inference Using YOLO
# # Use the yolo command to run predictions with your trained weights
# !yolo task=detect mode=predict model={weights_path} source={dataset_path} project={output_path} name=predictions

# # Step 5: Display Predicted Images in a Grid
# # Get a list of all predicted image files in the output folder
# predicted_images_dir = os.path.join(output_path, 'predictions')
# image_files = [f for f in os.listdir(predicted_images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# # Define grid parameters
# images_per_row = 5  # Number of images per row
# num_images = len(image_files)
# num_rows = math.ceil(num_images / images_per_row)  # Calculate number of rows

# # Create a grid of subplots
# fig, axes = plt.subplots(num_rows, images_per_row, figsize=(20, 4 * num_rows))
# axes = axes.flatten()  # Flatten the axes array for easy iteration

# # Load and display images in the grid
# for i, ax in enumerate(axes):
#     if i < num_images:  # Only process valid image indices
#         try:
#             # Load the image
#             img_path = os.path.join(predicted_images_dir, image_files[i])
#             img = Image.open(img_path)
            
#             # Display the image
#             ax.imshow(img)
#             ax.set_title(os.path.basename(img_path), fontsize=10)
#             ax.axis('off')  # Turn off axis for better visualization
#         except Exception as e:
#             ax.set_title("Error loading image", fontsize=10)
#             ax.axis('off')
#             print(f"Error loading image {img_path}: {e}")
#     else:
#         # Hide unused subplots
#         ax.axis('off')

# # Adjust layout to prevent overlap
# plt.tight_layout()
# plt.show()

# %%
# # Step 3: Define Paths
# weights_path = '/kaggle/working/runs/train_results3/weights/best.pt'  # Path to your trained weights
# dataset_path = '/kaggle/input/egy-platesv1/Egy_Plates_Imgs'  # Path to the dataset folder containing test images
# output_path = '/kaggle/working/predictions2'   # Path to save prediction outputs

# # Create the output directory if it doesn't exist
# os.makedirs(output_path, exist_ok=True)

# # Step 4: Run Inference Using YOLO
# # Use the yolo command to run predictions with your trained weights
# !yolo task=detect mode=predict model={weights_path} source={dataset_path} project={output_path} name=predictions

# # Step 5: Display Predicted Images in a Grid
# # Get a list of all predicted image files in the output folder
# predicted_images_dir = os.path.join(output_path, 'predictions')
# image_files = [f for f in os.listdir(predicted_images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# # Define grid parameters
# images_per_row = 5  # Number of images per row
# num_images = len(image_files)
# num_rows = math.ceil(num_images / images_per_row)  # Calculate number of rows

# # Create a grid of subplots
# fig, axes = plt.subplots(num_rows, images_per_row, figsize=(20, 4 * num_rows))
# axes = axes.flatten()  # Flatten the axes array for easy iteration

# # Load and display images in the grid
# for i, ax in enumerate(axes):
#     if i < num_images:  # Only process valid image indices
#         try:
#             # Load the image
#             img_path = os.path.join(predicted_images_dir, image_files[i])
#             img = Image.open(img_path)
            
#             # Display the image
#             ax.imshow(img)
#             ax.set_title(os.path.basename(img_path), fontsize=10)
#             ax.axis('off')  # Turn off axis for better visualization
#         except Exception as e:
#             ax.set_title("Error loading image", fontsize=10)
#             ax.axis('off')
#             print(f"Error loading image {img_path}: {e}")
#     else:
#         # Hide unused subplots
#         ax.axis('off')

# # Adjust layout to prevent overlap
# plt.tight_layout()
# plt.show()

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="DTywvqb9qrh51hE7n9XR")
project = rf.workspace("ealprainshams").project("ealpr-awask")
version = project.version(1)
dataset = version.download("yolov11")
# Out:
# Collecting roboflow
#   Downloading roboflow-1.1.54-py3-none-any.whl.metadata (9.7 kB)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from roboflow) (2025.1.31)
# Collecting idna==3.7 (from roboflow)
#   Downloading idna-3.7-py3-none-any.whl.metadata (9.9 kB)
# Requirement already satisfied: cycler in /usr/local/lib/python3.10/dist-packages (from roboflow) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.4.7)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from roboflow) (3.7.5)
# Requirement already satisfied: numpy>=1.18.5 in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.26.4)
# Requirement already satisfied: opencv-python-headless==4.10.0.84 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.10.0.84)
# Requirement already satisfied: Pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from roboflow) (11.0.0)
# Requirement already satisfied: python-dateutil in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.9.0.post0)
# Collecting python-dotenv (from roboflow)
#   Downloading python_dotenv-1.0.1-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.32.3)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.17.0)
# Requirement already satisfied: urllib3>=1.26.6 in /usr/local/lib/python3.10/dist-packages (from roboflow) (2.3.0)
# Requirement already satisfied: tqdm>=4.41.0 in /usr/local/lib/python3.10/dist-packages (from roboflow) (4.67.1)
# Requirement already satisfied: PyYAML>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from roboflow) (6.0.2)
# Requirement already satisfied: requests-toolbelt in /usr/local/lib/python3.10/dist-packages (from roboflow) (1.0.0)
# Collecting filetype (from roboflow)
#   Downloading filetype-1.2.0-py2.py3-none-any.whl.metadata (6.5 kB)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy>=1.18.5->roboflow) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (1.3.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (4.55.3)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->roboflow) (3.2.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->roboflow) (3.4.1)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.18.5->roboflow) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy>=1.18.5->roboflow) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy>=1.18.5->roboflow) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy>=1.18.5->roboflow) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy>=1.18.5->roboflow) (2024.2.0)
# Downloading roboflow-1.1.54-py3-none-any.whl (83 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 83.1/83.1 kB 3.7 MB/s eta 0:00:00
# Downloading idna-3.7-py3-none-any.whl (66 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 4.5 MB/s eta 0:00:00
# Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Downloading python_dotenv-1.0.1-py3-none-any.whl (19 kB)
# Installing collected packages: filetype, python-dotenv, idna, roboflow
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-decision-forests 1.10.0 requires tensorflow==2.17.0, but you have tensorflow 2.17.1 which is incompatible.
# Successfully installed filetype-1.2.0 idna-3.7 python-dotenv-1.0.1 roboflow-1.1.54
# loading Roboflow workspace...
# loading Roboflow project...
# Downloading Dataset Version Zip in EALPR-1 to yolov11:: 100%|██████████| 406882/406882 [00:05<00:00, 74776.80it/s]
# Extracting Dataset Version Zip to EALPR-1 in yolov11:: 100%|██████████| 10966/10966 [00:01<00:00, 6559.51it/s]

# %%
#!yolo task=detect mode=train model=/kaggle/input/lisence-plate-detector-weights/tensorflow2/default/1/best.pt data='/kaggle/working/EALPR-1/data.yaml' epochs=50 imgsz=640 device=0,1 batch=128 project=/kaggle/working/runs name=fine_tuned_results save_period=25

# %%
# import os
# from PIL import Image
# import matplotlib.pyplot as plt
# # Define the path to the train_results3 folder
# folder_path = '/kaggle/working/runs/fine_tuned_results'

# # Get a list of all image files in the folder
# image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# # Load and display images in separate figures
# for image_file in image_files:
#     # Load the image
#     img_path = os.path.join(folder_path, image_file)
#     img = Image.open(img_path)
    
#     # Create a new figure for each image
#     plt.figure(figsize=(8, 6))
#     plt.imshow(img)
#     plt.title(os.path.basename(img_path))
#     plt.axis('off')
#     plt.show()

# %%
# Step 1: Install Required Libraries
# !pip install ultralytics matplotlib pillow

# Step 2: Import Libraries
import os
from PIL import Image
import matplotlib.pyplot as plt
import math

# Step 3: Define Paths
weights_path = '/kaggle/input/lisence-plate-detector-weights/tensorflow2/default/1/best.pt'  # Path to your trained weights
dataset_path = '/kaggle/input/egy-carsv1'  # Path to the dataset folder containing test images
output_path = '/kaggle/working/predictions'   # Path to save prediction outputs

# Create the output directory if it doesn't exist
os.makedirs(output_path, exist_ok=True)

# Step 4: Run Inference Using YOLO
# Use the yolo command to run predictions with your trained weights
print("Running YOLO inference...")
# !yolo task=detect mode=predict model={weights_path} source={dataset_path} project={output_path} name=predictions

# Step 5: Verify Predictions Folder
predicted_images_dir = os.path.join(output_path, 'predictions')
if not os.path.exists(predicted_images_dir):
    print(f"Error: Predictions folder '{predicted_images_dir}' not found.")
else:
    # Get a list of all predicted image files in the output folder
    image_files = [f for f in os.listdir(predicted_images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

    if not image_files:
        print("No predicted images found in the folder.")
    else:
        # Step 6: Display Predicted Images in a Grid
        num_images = len(image_files)
        images_per_row = 5  # Number of images per row
        num_rows = math.ceil(num_images / images_per_row)  # Calculate number of rows

        # Create a grid of subplots
        fig, axes = plt.subplots(num_rows, images_per_row, figsize=(20, 4 * num_rows))
        axes = axes.flatten()  # Flatten the axes array for easy iteration

        # Load and display images in the grid
        for i, ax in enumerate(axes):
            if i < num_images:  # Only process valid image indices
                try:
                    # Load the image
                    img_path = os.path.join(predicted_images_dir, image_files[i])
                    img = Image.open(img_path)
                    
                    # Display the image
                    ax.imshow(img)
                    ax.set_title(os.path.basename(img_path), fontsize=10)
                    ax.axis('off')  # Turn off axis for better visualization
                except Exception as e:
                    ax.set_title("Error loading image", fontsize=10)
                    ax.axis('off')
                    print(f"Error loading image {img_path}: {e}")
            else:
                # Hide unused subplots
                ax.axis('off')

        # Adjust layout to prevent overlap
        plt.tight_layout()

        # Save the grid as an image file in /kaggle/working/
        output_grid_path = '/kaggle/working/output_grid.png'
        plt.savefig(output_grid_path, bbox_inches='tight', pad_inches=0.1)
        print(f"Grid saved to {output_grid_path}")

        # Display the grid in the notebook
        plt.show()
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.3.81)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (11.0.0)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Running YOLO inference...
# Ultralytics 8.3.81 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/cfg/__init__.py", line 986, in entrypoint
#     getattr(model, mode)(**overrides)  # default args from model
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/model.py", line 560, in predict
#     return self.predictor.predict_cli(source=source) if is_cli else self.predictor(source=source, stream=stream)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py", line 190, in predict_cli
#     for _ in gen:  # sourcery skip: remove-empty-nested-block, noqa
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/_contextlib.py", line 36, in generator_context
#     response = gen.send(None)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py", line 233, in stream_inference
#     self.setup_source(source if source is not None else self.args.source)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/engine/predictor.py", line 205, in setup_source
#     self.dataset = load_inference_source(
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/data/build.py", line 214, in load_inference_source
#     dataset = LoadImagesAndVideos(source, batch=batch, vid_stride=vid_stride)
#   File "/usr/local/lib/python3.10/dist-packages/ultralytics/data/loaders.py", line 365, in __init__
#     raise FileNotFoundError(f"No images or videos found in {p}. {FORMATS_HELP_MSG}")
# FileNotFoundError: No images or videos found in /kaggle/input/egy-carsv1. Supported formats are:
# images: {'pfm', 'dng', 'png', 'webp', 'jpg', 'mpo', 'bmp', 'jpeg', 'heic', 'tif', 'tiff'}
# videos: {'ts', 'mpeg', 'mp4', 'mkv', 'webm', 'wmv', 'gif', 'asf', 'mov', 'mpg', 'm4v', 'avi'}
# Error: Predictions folder '/kaggle/working/predictions/predictions' not found.

# %%
# # Step 3: Define Paths
# weights_path = '/kaggle/working/runs/fine_tuned_results/weights/best.pt'  # Path to your trained weights
# dataset_path = '/kaggle/input/egy-platesv1/Egy_Plates_Imgs'  # Path to the dataset folder containing test images
# output_path = '/kaggle/working/predictions2'   # Path to save prediction outputs

# # Create the output directory if it doesn't exist
# os.makedirs(output_path, exist_ok=True)

# # Step 4: Run Inference Using YOLO
# # Use the yolo command to run predictions with your trained weights
# !yolo task=detect mode=predict model={weights_path} source={dataset_path} project={output_path} name=predictions

# # Step 5: Display Predicted Images in a Grid
# # Get a list of all predicted image files in the output folder
# predicted_images_dir = os.path.join(output_path, 'predictions')
# image_files = [f for f in os.listdir(predicted_images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# # Define grid parameters
# images_per_row = 5  # Number of images per row
# num_images = len(image_files)
# num_rows = math.ceil(num_images / images_per_row)  # Calculate number of rows

# # Create a grid of subplots
# fig, axes = plt.subplots(num_rows, images_per_row, figsize=(20, 4 * num_rows))
# axes = axes.flatten()  # Flatten the axes array for easy iteration

# # Load and display images in the grid
# for i, ax in enumerate(axes):
#     if i < num_images:  # Only process valid image indices
#         try:
#             # Load the image
#             img_path = os.path.join(predicted_images_dir, image_files[i])
#             img = Image.open(img_path)
            
#             # Display the image
#             ax.imshow(img)
#             ax.set_title(os.path.basename(img_path), fontsize=10)
#             ax.axis('off')  # Turn off axis for better visualization
#         except Exception as e:
#             ax.set_title("Error loading image", fontsize=10)
#             ax.axis('off')
#             print(f"Error loading image {img_path}: {e}")
#     else:
#         # Hide unused subplots
#         ax.axis('off')

# # Adjust layout to prevent overlap
# plt.tight_layout()
# plt.show()

# %%
import os
import cv2
from ultralytics import YOLO
import matplotlib.pyplot as plt

# Step 1: Load the trained YOLO model
model_path = '/kaggle/input/lisence-plate-detector-weights/tensorflow2/default/1/best.pt'
model = YOLO(model_path)

# Step 2: Define the folder containing images
image_folder = '/kaggle/input/egycar-vs-distance/plate_Vs_distance'

# Step 3: Initialize lists to store distances and confidence scores
distances = []
confidence_scores = []

# Step 4: Process each image in the folder
for filename in os.listdir(image_folder):
    if filename.endswith('.jpg') or filename.endswith('.png'):
        # Extract distance from the filename
        distance = int(filename.split('m')[0])
        
        # Load the image
        image_path = os.path.join(image_folder, filename)
        image = cv2.imread(image_path)
        
        # Run inference
        results = model.predict(source=image, save=False, imgsz=640)
        
        # Extract confidence scores for license plate detections
        confidences = [float(conf) for conf in results[0].boxes.conf.cpu().numpy()]
        boxes = results[0].boxes.xyxy.cpu().numpy()
        
        # Assuming there is only one license plate per image, take the highest confidence score
        if confidences:
            max_confidence = max(confidences)
            distances.append(distance)
            confidence_scores.append(max_confidence)
            
            # Display the image with the detected bounding box and confidence score
            for box, conf in zip(boxes, confidences):
                x_min, y_min, x_max, y_max = map(int, box)
                cv2.rectangle(image, (x_min, y_min), (x_max, y_max), (0, 255, 0), 2)
                cv2.putText(image, f"Confidence: {conf:.2f}", (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)
            
            # Convert BGR to RGB for displaying with matplotlib
            image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
            plt.figure(figsize=(10, 6))
            plt.imshow(image_rgb)
            plt.title(f'Distance: {distance}m, Confidence: {max_confidence:.2f}')
            plt.axis('off')
            plt.show()
        else:
            print(f"No license plate detected in image at {distance}m")

# Step 5: Plot distance vs. confidence
plt.figure(figsize=(10, 6))
plt.plot(distances, confidence_scores, marker='o', linestyle='-', color='b')
plt.title('License Plate Detection Confidence vs. Distance')
plt.xlabel('Distance (m)')
plt.ylabel('Confidence Score')
plt.grid(True)
plt.show()

# %%
from ultralytics import YOLO
import os
import matplotlib.pyplot as plt

# Load the pre-trained model
model = YOLO("/kaggle/input/lisence-plate-detector-weights/tensorflow2/default/1/best.pt")

# Define the path to the images directory
images_dir = '/kaggle/input/egycar-vs-distance/plate_Vs_distance'

# List all image files in the directory
image_files = [f for f in os.listdir(images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# Extract distances from filenames (assuming filenames are formatted as "Xm.jpg" where X is the distance)
distances = [int(f.split('m')[0]) for f in image_files]
image_paths = [os.path.join(images_dir, f) for f in image_files]

# Perform inference on each image
results = []
for img_path in image_paths:
    result = model(img_path)
    results.append(result)

# Calculate accuracy for each image
accuracies = []
for i, result in enumerate(results):
    # Check if any license plates were detected
    if len(result[0].boxes) > 0:
        accuracies.append(1)  # License plate detected
    else:
        accuracies.append(0)  # No license plate detected

# Create a scatter plot of distance vs. accuracy
plt.scatter(distances, accuracies)
plt.xlabel('Distance (m)')
plt.ylabel('Accuracy')
plt.title('Distance vs. Accuracy')
plt.grid(True)
plt.show()
# Out:
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/18m.jpeg: 640x384 (no detections), 59.3ms
# Speed: 6.0ms preprocess, 59.3ms inference, 54.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/6m.jpeg: 640x384 1 License_Plate, 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 178.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/15m.jpeg: 640x384 1 License_Plate, 9.3ms
# Speed: 1.6ms preprocess, 9.3ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/9m.jpeg: 640x384 1 License_Plate, 8.7ms
# Speed: 1.4ms preprocess, 8.7ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/12m.jpeg: 640x384 1 License_Plate, 8.3ms
# Speed: 1.3ms preprocess, 8.3ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/3m.jpeg: 640x384 1 License_Plate, 8.2ms
# Speed: 1.4ms preprocess, 8.2ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# Create a scatter plot
plt.scatter([1, 2, 3], [4, 5, 6])
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Test Plot')
plt.show()  # This is necessary to display the plot

# %%
from ultralytics import YOLO
import os
import matplotlib.pyplot as plt

# Ensure plots are displayed inline
# %matplotlib inline

# Load the pre-trained model
model = YOLO("/kaggle/input/lisence-plate-detector-weights/tensorflow2/default/1/best.pt")

# Define the path to the images directory
images_dir = '/kaggle/input/egycar-vs-distance/plate_Vs_distance'

# List all image files in the directory
image_files = [f for f in os.listdir(images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]

# Extract distances from filenames (assuming filenames are formatted as "Xm.jpg" where X is the distance)
distances = [int(f.split('m')[0]) for f in image_files]
image_paths = [os.path.join(images_dir, f) for f in image_files]

# Perform inference on each image
results = []
for img_path in image_paths:
    result = model(img_path)
    results.append(result)

# Calculate accuracy for each image
accuracies = []
for i, result in enumerate(results):
    # Check if any license plates were detected
    if len(result[0].boxes) > 0:
        accuracies.append(1)  # License plate detected
    else:
        accuracies.append(0)  # No license plate detected

# Debugging: Print distances and accuracies
print("Distances:", distances)
print("Accuracies:", accuracies)

# Create a scatter plot of distance vs. accuracy
plt.scatter(distances, accuracies)
plt.xlabel('Distance (m)')
plt.ylabel('Accuracy')
plt.title('Distance vs. Accuracy')
plt.grid(True)
plt.show()

# Save the plot as a file (optional)
plt.savefig('distance_vs_accuracy.png')  # Fixed the missing closing quote
plt.close()

# Display the saved plot (optional)
from IPython.display import Image
Image(filename='distance_vs_accuracy.png')
# Out:
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/18m.jpeg: 640x384 (no detections), 9.9ms
# Speed: 1.5ms preprocess, 9.9ms inference, 0.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/6m.jpeg: 640x384 1 License_Plate, 8.5ms
# Speed: 1.4ms preprocess, 8.5ms inference, 1.2ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/15m.jpeg: 640x384 1 License_Plate, 13.1ms
# Speed: 1.5ms preprocess, 13.1ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/9m.jpeg: 640x384 1 License_Plate, 14.0ms
# Speed: 1.6ms preprocess, 14.0ms inference, 1.9ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/12m.jpeg: 640x384 1 License_Plate, 13.3ms
# Speed: 1.7ms preprocess, 13.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 384)
#
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/3m.jpeg: 640x384 1 License_Plate, 8.6ms
# Speed: 1.4ms preprocess, 8.6ms inference, 1.1ms postprocess per image at shape (1, 3, 640, 384)
# Distances: [18, 6, 15, 9, 12, 3]
# Accuracies: [0, 1, 1, 1, 1, 1]

# %%
# Step 1: Install Required Libraries
# !pip install ultralytics matplotlib pillow

# Step 2: Import Libraries
import os
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np

# Step 3: Define Paths
weights_path = '/kaggle/input/lisence-plate-detector-weights/tensorflow2/default/1/best.pt'  # Path to your trained weights
dataset_path = '/kaggle/input/egycar-vs-distance/plate_Vs_distance'  # Path to the dataset folder containing test images
output_path = '/kaggle/working/predictions'   # Path to save prediction outputs

# Create the output directory if it doesn't exist
os.makedirs(output_path, exist_ok=True)

# Step 4: Run Inference Using YOLO
# Use the yolo command to run predictions with your trained weights
print("Running YOLO inference...")
# !yolo task=detect mode=predict model={weights_path} source={dataset_path} project={output_path} name=predictions

# Step 5: Verify Predictions Folder
predicted_images_dir = os.path.join(output_path, 'predictions5')
if not os.path.exists(predicted_images_dir):
    print(f"Error: Predictions folder '{predicted_images_dir}' not found.")
else:
    # Get a list of all predicted image files in the output folder
    image_files = [f for f in os.listdir(predicted_images_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    if not image_files:
        print("No predicted images found in the folder.")
    else:
        # Load the YOLO model for inference
        from ultralytics import YOLO
        model = YOLO(weights_path)

        # Process each image
        for image_file in image_files:
            try:
                # Load the image
                img_path = os.path.join(predicted_images_dir, image_file)
                img = cv2.imread(img_path)
                img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)  # Convert BGR to RGB for matplotlib

                # Run inference on the image
                results = model.predict(source=img_path, save=False, imgsz=640)

                # Extract detections
                boxes = results[0].boxes.xyxy.cpu().numpy()  # Bounding box coordinates
                confidences = results[0].boxes.conf.cpu().numpy()  # Confidence scores

                # Display the image without annotations
                plt.figure(figsize=(10, 6))
                plt.imshow(img_rgb)
                plt.title(f"Image: {image_file}", fontsize=12)
                plt.axis('off')
                plt.show()

                # Print results for the image
                print(f"Results for {image_file}:")
                for i, (box, conf) in enumerate(zip(boxes, confidences)):
                    x_min, y_min, x_max, y_max = map(int, box)
                    print(f"  Detection {i + 1}: BBox=[{x_min}, {y_min}, {x_max}, {y_max}], Confidence={conf:.2f}")

            except Exception as e:
                print(f"Error processing image {image_file}: {e}")
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.3.81)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: pillow in /usr/local/lib/python3.10/dist-packages (11.0.0)
# Requirement already satisfied: numpy<=2.1.1,>=1.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy<=2.1.1,>=1.23.0->ultralytics) (2.4.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy<=2.1.1,>=1.23.0->ultralytics) (2024.2.0)
# Running YOLO inference...
# Ultralytics 8.3.81 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15095MiB)
# YOLO11n summary (fused): 100 layers, 2,582,347 parameters, 0 gradients, 6.3 GFLOPs
#
# image 1/6 /kaggle/input/egycar-vs-distance/plate_Vs_distance/12m.jpeg: 640x384 1 License_Plate, 50.1ms
# image 2/6 /kaggle/input/egycar-vs-distance/plate_Vs_distance/15m.jpeg: 640x384 1 License_Plate, 9.3ms
# image 3/6 /kaggle/input/egycar-vs-distance/plate_Vs_distance/18m.jpeg: 640x384 (no detections), 7.9ms
# image 4/6 /kaggle/input/egycar-vs-distance/plate_Vs_distance/3m.jpeg: 640x384 1 License_Plate, 7.7ms
# image 5/6 /kaggle/input/egycar-vs-distance/plate_Vs_distance/6m.jpeg: 640x384 1 License_Plate, 7.5ms
# image 6/6 /kaggle/input/egycar-vs-distance/plate_Vs_distance/9m.jpeg: 640x384 1 License_Plate, 7.7ms
# Speed: 1.7ms preprocess, 15.0ms inference, 28.6ms postprocess per image at shape (1, 3, 640, 384)
# Results saved to /kaggle/working/predictions/predictions
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
# Error: Predictions folder '/kaggle/working/predictions/predictions5' not found.

# %%
pip install opencv-python-headless ultralytics numpy
# Out:
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.3.81)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy) (2024.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import torch

# Check if GPU is available
if torch.cuda.is_available():
    print("GPU is available!")
    device = torch.device("cuda")  # Use GPU
else:
    print("GPU is not available, using CPU instead.")
    device = torch.device("cpu")
# Out:
# GPU is available!

# %%
# !pip install ultralytics opencv-python-headless numpy matplotlib
# Out:
# Requirement already satisfied: ultralytics in /usr/local/lib/python3.10/dist-packages (8.3.81)
# Requirement already satisfied: opencv-python-headless in /usr/local/lib/python3.10/dist-packages (4.10.0.84)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (1.26.4)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.10.0.84)
# Requirement already satisfied: pillow>=7.1.2 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (11.0.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (1.13.1)
# Requirement already satisfied: torch>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.5.1+cu121)
# Requirement already satisfied: torchvision>=0.9.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.20.1+cu121)
# Requirement already satisfied: tqdm>=4.64.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (4.67.1)
# Requirement already satisfied: psutil in /usr/local/lib/python3.10/dist-packages (from ultralytics) (5.9.5)
# Requirement already satisfied: py-cpuinfo in /usr/local/lib/python3.10/dist-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (0.12.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ultralytics) (2.0.14)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.10/dist-packages (from numpy) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.10/dist-packages (from numpy) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.10/dist-packages (from numpy) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.10/dist-packages (from numpy) (2025.0.1)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.10/dist-packages (from numpy) (2022.0.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.10/dist-packages (from numpy) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=1.1.4->ultralytics) (2025.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.23.0->ultralytics) (2025.1.31)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.17.0)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.8.0->ultralytics) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy==1.13.1->torch>=1.8.0->ultralytics) (1.3.0)
# Requirement already satisfied: intel-openmp>=2024 in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.10/dist-packages (from mkl->numpy) (2022.0.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.10/dist-packages (from tbb==2022.*->mkl->numpy) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.10/dist-packages (from mkl_umath->numpy) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.10/dist-packages (from intel-openmp>=2024->mkl->numpy) (2024.2.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.8.0->ultralytics) (3.0.2)

# %%
import cv2
import numpy as np
from ultralytics import YOLO
from IPython.display import Image, display

# Step 1: Define the deskewing function
def deskew(image):
    """
    Deskew the image to align text horizontally.
    :param image: Input image.
    :return: Deskewed image.
    """
    coords = np.column_stack(np.where(image > 0))
    angle = cv2.minAreaRect(coords)[-1]
    if angle < -45:
        angle = -(90 + angle)
    else:
        angle = -angle
    (h, w) = image.shape[:2]
    center = (w // 2, h // 2)
    M = cv2.getRotationMatrix2D(center, angle, 1.0)
    rotated = cv2.warpAffine(image, M, (w, h), flags=cv2.INTER_CUBIC, borderMode=cv2.BORDER_REPLICATE)
    return rotated

# Step 2: Load the trained YOLO model
model_path = '/kaggle/input/lisence-plate-detector-weights/tensorflow2/default/1/best.pt'
model = YOLO(model_path)

# Step 3: Download and load the input image
image_url = '/kaggle/input/egycar-vs-distance/plate_Vs_distance/3m.jpeg'
image_path = '/kaggle/input/egycar-vs-distance/plate_Vs_distance/3m.jpeg'

# Download the image
# !wget -q {image_url} -O {image_path}

# Load the image using OpenCV
original_image = cv2.imread(image_path)
if original_image is None:
    print("Error: Failed to load the image.")
else:
    print("Step 1: Original Image Loaded Successfully")
    display(Image(filename=image_path))  # Display the original image

    # Step 4: Run inference to detect license plates
    results = model.predict(source=image_path, save=False, imgsz=640)

    # Extract bounding boxes from the results
    boxes = results[0].boxes.xyxy.cpu().numpy()  # Get bounding box coordinates
    confidences = results[0].boxes.conf.cpu().numpy()  # Get confidence scores
    class_ids = results[0].boxes.cls.cpu().numpy()  # Get class IDs

    print(f"\nStep 2: Detected {len(boxes)} objects in the image.")

    # Step 5: Process each detected region
    for i, box in enumerate(boxes):
        # Extract bbox coordinates
        x_min, y_min, x_max, y_max = map(int, box)
        confidence = confidences[i]
        class_id = int(class_ids[i])

        print(f"\nProcessing Detection {i + 1}:")
        print(f"  Class ID: {class_id}, Confidence: {confidence:.2f}")
        print(f"  Bounding Box: [x_min={x_min}, y_min={y_min}, x_max={x_max}, y_max={y_max}]")

        # Crop the detected region
        cropped_region = original_image[y_min:y_max, x_min:x_max]
        cropped_path = f'/kaggle/working/cropped_region_{i}.jpg'
        cv2.imwrite(cropped_path, cropped_region)  # Save the cropped region
        print("\nStep 3: Cropped Region")
        display(Image(filename=cropped_path))  # Display the cropped region

        # Convert to grayscale
        gray_img = cv2.cvtColor(cropped_region, cv2.COLOR_BGR2GRAY)
        gray_path = f'/kaggle/working/gray_image_{i}.jpg'
        cv2.imwrite(gray_path, gray_img)  # Save the grayscale image
        print("\nStep 4: Grayscale Image")
        display(Image(filename=gray_path))  # Display the grayscale image

        # Apply thresholding
        _, binary_img = cv2.threshold(gray_img, 0, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
        binary_path = f'/kaggle/working/binary_image_{i}.jpg'
        cv2.imwrite(binary_path, binary_img)  # Save the binary image
        print("\nStep 5: Binary Image (Thresholded)")
        display(Image(filename=binary_path))  # Display the binary image

        # Remove noise using morphological operations
        kernel = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
        cleaned_img = cv2.morphologyEx(binary_img, cv2.MORPH_CLOSE, kernel)
        cleaned_path = f'/kaggle/working/cleaned_image_{i}.jpg'
        cv2.imwrite(cleaned_path, cleaned_img)  # Save the cleaned image
        print("\nStep 6: Cleaned Image (Noise Removed)")
        display(Image(filename=cleaned_path))  # Display the cleaned image

        # Deskew the image
        deskewed_img = deskew(cleaned_img)
        deskewed_path = f'/kaggle/working/deskewed_image_{i}.jpg'
        cv2.imwrite(deskewed_path, deskewed_img)  # Save the deskewed image
        print("\nStep 7: Deskewed Image (Text Aligned)")
        display(Image(filename=deskewed_path))  # Display the deskewed image

        # Resize the image
        resized_img = cv2.resize(deskewed_img, (300, 75))  # Resize to standard dimensions
        resized_path = f'/kaggle/working/resized_image_{i}.jpg'
        cv2.imwrite(resized_path, resized_img)  # Save the resized image
        print("\nStep 8: Resized Image")
        display(Image(filename=resized_path))  # Display the resized image

        # Enhance contrast using histogram equalization
        enhanced_img = cv2.equalizeHist(resized_img)
        enhanced_path = f'/kaggle/working/enhanced_image_{i}.jpg'
        cv2.imwrite(enhanced_path, enhanced_img)  # Save the enhanced image
        print("\nStep 9: Enhanced Image (Contrast Improved)")
        display(Image(filename=enhanced_path))  # Display the enhanced image
# Out:
# /kaggle/input/egycar-vs-distance/plate_Vs_distance/3m.jpeg: Read-only file system
# Step 1: Original Image Loaded Successfully
# image 1/1 /kaggle/input/egycar-vs-distance/plate_Vs_distance/3m.jpeg: 640x384 1 License_Plate, 9.7ms
# Speed: 1.8ms preprocess, 9.7ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# Step 2: Detected 1 objects in the image.
#
# Processing Detection 1:
#   Class ID: 0, Confidence: 0.79
#   Bounding Box: [x_min=259, y_min=378, x_max=385, y_max=451]
#
# Step 3: Cropped Region
# Step 4: Grayscale Image
# Step 5: Binary Image (Thresholded)
# Step 6: Cleaned Image (Noise Removed)
# Step 7: Deskewed Image (Text Aligned)
# Step 8: Resized Image
# Step 9: Enhanced Image (Contrast Improved)
